# %%
import os
import argparse

import torch

import mixed_precision
from stats import StatTracker
from datasets2 import Dataset, build_dataset, get_dataset, get_encoder_size
from model_grad import Model
from checkpoint import Checkpoint
from task_self_supervised import train_self_supervised
from task_classifiers import train_classifiers


parser = argparse.ArgumentParser(description='Infomax Representations -- Self-Supervised Training')
parser.add_argument("--verbosity", help="increase output verbosity")
# parameters for general training stuff
parser.add_argument('--dataset', type=str, default='STL10')
parser.add_argument('--batch_size', type=int, default=200,
                    help='input batch size (default: 200)')
parser.add_argument('--learning_rate', type=float, default=0.0002,
                    help='learning rate')
parser.add_argument('--seed', type=int, default=1,
                    help='random seed (default: 1)')
parser.add_argument('--amp', action='store_true', default=False,
                    help='Enables automatic mixed precision')

# parameters for model and training objective
parser.add_argument('--classifiers', action='store_true', default=False,
                    help="Wether to run self-supervised encoder or"
                    "classifier training task")
parser.add_argument('--ndf', type=int, default=64,
                    help='feature width for encoder')
parser.add_argument('--n_rkhs', type=int, default=1024,
                    help='number of dimensions in fake RKHS embeddings')
parser.add_argument('--tclip', type=float, default=20.0,
                    help='soft clipping range for NCE scores')
parser.add_argument('--n_depth', type=int, default=8)
parser.add_argument('--use_bn', type=int, default=1)

# parameters for output, logging, checkpointing, etc
parser.add_argument('--output_dir', type=str, default='./runs',
                    help='directory where tensorboard events and checkpoints will be stored')
parser.add_argument('--input_dir', type=str, default='/root/data/ILSVRC/Data/CLS-LOC/',
                    help="Input directory for the dataset. Not needed For C10,"
                    " C100 or STL10 as the data will be automatically downloaded.")
parser.add_argument('--cpt_load_path', type=str, default='abc.xyz',
                    help='path from which to load checkpoint (if available)')
parser.add_argument('--cpt_name', type=str, default='cifar_amdim_cpt.pth',
                    help='name to use for storing checkpoints during training')
parser.add_argument('--run_name', type=str, default='cifar_default_run',
                    help='name to use for the tensorbaord summary for this run')
# ...
args = parser.parse_args(args=[])

# create target output dir if it doesn't exist yet
if not os.path.isdir(args.output_dir):
    os.mkdir(args.output_dir)

# enable mixed-precision computation if desired
if args.amp:
    mixed_precision.enable_mixed_precision()

# set the RNG seeds (probably more hidden elsewhere...)
torch.manual_seed(args.seed)
torch.cuda.manual_seed(args.seed)

# get the dataset
dataset = get_dataset(args.dataset)
enc_size = get_encoder_size(dataset)

# get a helper object for tensorboard logging
log_dir = os.path.join(args.output_dir, args.run_name)
stat_tracker = StatTracker(log_dir=log_dir)

# get dataloaders for training and testing
# train_loader, test_loader, num_classes = \
#     build_dataset(dataset=dataset,
#                   batch_size=args.batch_size,
#                   input_dir=args.input_dir,
#                   labeled_only=True)

num_classes = 10
torch_device = torch.device('cuda')
# create new model with random parameters
model = Model(ndf=args.ndf, n_classes=num_classes, n_rkhs=args.n_rkhs,
              tclip=args.tclip, n_depth=args.n_depth, enc_size=enc_size,
              use_bn=(args.use_bn == 1))
model.init_weights(init_scale=1.0)
# restore model parameters from a checkpoint if requested
checkpoint = Checkpoint(model, args.cpt_load_path, args.output_dir, args.cpt_name)
model = model.to(torch_device)

# select which type of training to do
task = train_classifiers if args.classifiers else train_self_supervised

# the pretrained model 
ckpt=torch.load('/root/amdim-public/runs_stl64_norm_BN/cifar_amdim_cpt.pth')
params = ckpt['model']
from collections import OrderedDict
new_state_dict = OrderedDict()
for k, v in params.items():
    name = k.replace("module.", "")
    new_state_dict[name] = v
# print(new_state_dict)
model.load_state_dict(new_state_dict)
# model.load_state_dict(params)
# Out:
# log_dir: ./runs/cifar_default_run
# Using a 64x64 encoder
# ***** CHECKPOINTING ****************
# No checkpoint found. Starting fresh.
# ************************************
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
from datasets_bn import Dataset, build_dataset_whole, get_dataset, get_encoder_size
dataset = get_dataset(args.dataset)
train_loader, test_loader, num_classes = \
    build_dataset_whole(dataset=dataset,
                  batch_size=args.batch_size,
                  input_dir=args.input_dir,
                  labeled_only=True)
x_train, y_train = iter(train_loader).next()
# x_train,_=x_train
x_test, y_test = iter(test_loader).next()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import logging
import os
import time

import numpy as np
import matplotlib.pyplot as plt
import foolbox
import torch
import torch.backends.cudnn as cudnn
import torch.nn as nn
import torch.optim as optim

from lib.dataset_utils import *
from lib.cifar_resnet import *
from lib.adv_model import *
from lib.dknn_attack import DKNNAttack

from lib.dknn_attack import DKNNAttack

from lib.cwl2_attack import CWL2Attack
from lib.dknn_stl3 import  DKNNL2
from lib.utils import *
from lib.lip_model import *
from lib.knn import *
from lib.nin import *
from lib.cifar10_model import *

from lib.cifar10_dcgan import Discriminator, Generator

from NCE.NCEAverage import NCEAverage
from NCE.NCECriterion import NCECriterion


def set_model(n_data):
    contrast = NCEAverage(128, n_data, 4096, 0.1, 0.5)
    criterion_l = NCECriterion(n_data)
    criterion_ab = NCECriterion(n_data)

    if torch.cuda.is_available():
        contrast = contrast.cuda()
        criterion_ab = criterion_ab.cuda()
        criterion_l = criterion_l.cuda()
        cudnn.benchmark = True

    return contrast, criterion_ab, criterion_l


def set_optimizer(model):
    # return optimizer
    optimizer = torch.optim.SGD(model.parameters(),
                                lr=0.001,
                                momentum=0.9,
                                weight_decay=0.4)
    return optimizer



layers = ['encode']
num = 10000
dknn = DKNNL2(model, x_train, y_train, x_test, y_test, layers,
              k=75, num_classes=10)

with torch.no_grad():
    y_pred = dknn.classify(x_test)
    ind = np.where(y_pred.argmax(1) == y_test.numpy())[0]
    print((y_pred.argmax(1) == y_test.numpy()).sum() / y_test.size(0))


from lib.pgd_norm_stl import DKNNPGDAttack

import pickle

attack = DKNNPGDAttack()

layer = 'encoder'


def attack_batch(x, y, batch_size, layer):
    x_a = torch.zeros_like(x)
    total_num = x.size(0)
    num_batches = total_num // batch_size
    for i in range(num_batches):
        begin = i * batch_size
        end = (i + 1) * batch_size

        x_a[begin:end] = attack(
            dknn, x[begin:end], y[begin:end],
            guide_layer=layer, m=300, binary_search_steps=20,
            max_iterations=1000, learning_rate=1e-2, initial_const=1e-3,
            abort_early=False, random_start=True, guide=2,epsilon=0.06, step = 20, step_size = 0.005)
    return x_a


num = 100
ind = np.where(y_pred.argmax(1) == y_test.numpy())[0]
x_adv = attack_batch(x_test[ind][:num].cuda(), y_test[ind][:num], 10,layer)
model_name = 'amdim003_stl'
pickle.dump(x_adv.cpu().detach(), open('x_adv_' + model_name + '.p', 'wb'))
y_pred = dknn.classify(x_adv)
acc = (y_pred.argmax(1) == y_test[ind][:num].numpy()).sum() / len(y_pred)
print(acc)

class AverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count


batch_time = AverageMeter()
data_time = AverageMeter()
losses = AverageMeter()
l_loss_meter = AverageMeter()
ab_loss_meter = AverageMeter()
l_prob_meter = AverageMeter()
ab_prob_meter = AverageMeter()


# optimizer = set_optimizer(model)
mods_inf = [m for m in model.info_modules]
optimizer = optim.Adam(
    [{'params': mod.parameters(), 'lr': 0.0001} for mod in mods_inf],
    betas=(0.8, 0.999), weight_decay=1e-5, eps=1e-8)



batch_size =100
for epoch in range(10):
    for i in range(50):
        print(i)
        begin = i * batch_size
        end = (i + 1) * batch_size
        x_ori = x_train[begin:end].cuda()
        x_a = torch.zeros_like(x_ori).cuda()
        y_ori = y_train[begin:end].cuda()
    #         model.eval()
        #         with torch.no_grad():

        # num = 20000
        dknn = DKNNL2(model, x_train, y_train, x_test, y_test, layers, k=75, num_classes=10)

        x_a = attack(
            dknn, x_ori, y_ori,
            guide_layer=layer, m=300, binary_search_steps=10,
            max_iterations=10, learning_rate=1e-2, initial_const=1e-5,
            abort_early=False, random_start=True, guide=2,epsilon=0.03, step = 10, step_size = 0.005)

        y_pred = dknn.classify(x_a)
        ind = np.where(y_pred.argmax(1) != y_ori.cpu().numpy())[0]
        index = torch.LongTensor(list(range(begin, end)))
        x_a = x_a[ind]
        x_ori = x_ori[ind]
        y_ori = y_ori[ind]
        index = index[ind]

        model.train()

        bsz = x_ori.size(0)
        inputs = x_ori.float()
        inputs_adv = x_a.detach().float()
        if torch.cuda.is_available():
            index = index.cuda()
            inputs = inputs.cuda()
            inputs_adv = inputs_adv.cuda()

            # ===================forward=====================
        if inputs.shape[0] == 1:
            inputs = torch.cat((inputs, inputs), 0)
            inputs_adv = torch.cat((inputs_adv, inputs_adv), 0)
            res_dict = model(x1=inputs, x2=inputs_adv, class_only=False)
            lgt_glb_mlp, lgt_glb_lin = res_dict['class']
            # compute costs for all self-supervised tasks
            loss_g2l = (res_dict['g2l_1t5'] +
                        res_dict['g2l_1t7'] +
                        res_dict['g2l_5t5'])
            loss_inf = loss_g2l #+ res_dict['lgt_reg']
        else:
            res_dict = model(x1=inputs, x2=inputs_adv, class_only=False)
            lgt_glb_mlp, lgt_glb_lin = res_dict['class']
            # compute costs for all self-supervised tasks
            loss_g2l = (res_dict['g2l_1t5'] +
                        res_dict['g2l_1t7'] +
                        res_dict['g2l_5t5'])
            loss_inf = loss_g2l #+ res_dict['lgt_reg']

        loss = loss_inf

        # ===================backward=====================
        optimizer.zero_grad()
        mixed_precision.backward(loss, optimizer)
        optimizer.step()



        # print info
        if (i + 1) % 1 == 0:
            print('loss: {}'.format(loss.item()))


    #         if i == 50:
        ckpt_num = epoch*50+i
        if ckpt_num%5==0:
            print('==> Saving...')
            state = {
                'model': model.state_dict(),
                'i': ckpt_num,
            }
            torch.save(state, 'stl/lr0001_003_SAT_{}.pth'.format(ckpt_num))



        dknn = DKNNL2(model, x_train, y_train, x_test, y_test, layers, k=75, num_classes=10)
        with torch.no_grad():
            y_pred = dknn.classify(x_test)
            ind = np.where(y_pred.argmax(1) == y_test.numpy())[0]
            print((y_pred.argmax(1) == y_test.numpy()).sum() / y_test.size(0))

            y_pred = dknn.classify(x_a)
            print('adversarial example')
            print((y_pred.argmax(1) == y_ori.cpu().numpy()).sum()/x_a.shape[0])
# Out:
# 0.861375
# step 0 number of successful adv: 6/10
# step 1 number of successful adv: 7/10
# step 2 number of successful adv: 6/10
# step 3 number of successful adv: 8/10
# step 4 number of successful adv: 5/10
# step 5 number of successful adv: 7/10
# step 6 number of successful adv: 7/10
# step 7 number of successful adv: 7/10
# step 8 number of successful adv: 7/10
# step 9 number of successful adv: 9/10
# step 10 number of successful adv: 7/10
# step 11 number of successful adv: 9/10
# step 12 number of successful adv: 6/10
# step 13 number of successful adv: 9/10
# step 14 number of successful adv: 8/10
# step 15 number of successful adv: 9/10
# step 16 number of successful adv: 8/10
# step 17 number of successful adv: 9/10
# step 18 number of successful adv: 8/10
# step 19 number of successful adv: 8/10
# step 0 number of successful adv: 3/10
# step 1 number of successful adv: 4/10
# step 2 number of successful adv: 5/10
# step 3 number of successful adv: 5/10
# step 4 number of successful adv: 4/10
# step 5 number of successful adv: 4/10
# step 6 number of successful adv: 5/10
# step 7 number of successful adv: 5/10
# step 8 number of successful adv: 6/10
# step 9 number of successful adv: 4/10
# step 10 number of successful adv: 5/10
# step 11 number of successful adv: 4/10
# step 12 number of successful adv: 3/10
# step 13 number of successful adv: 5/10
# step 14 number of successful adv: 4/10
# step 15 number of successful adv: 4/10
# step 16 number of successful adv: 5/10
# step 17 number of successful adv: 5/10
# step 18 number of successful adv: 4/10
# step 19 number of successful adv: 5/10
# step 0 number of successful adv: 6/10
# step 1 number of successful adv: 7/10
# step 2 number of successful adv: 6/10
# step 3 number of successful adv: 6/10
# step 4 number of successful adv: 7/10
# step 5 number of successful adv: 7/10
# step 6 number of successful adv: 7/10
# step 7 number of successful adv: 7/10
# step 8 number of successful adv: 8/10
# step 9 number of successful adv: 7/10
# step 10 number of successful adv: 7/10
# step 11 number of successful adv: 7/10
# step 12 number of successful adv: 7/10
# step 13 number of successful adv: 7/10
# step 14 number of successful adv: 5/10
# step 15 number of successful adv: 7/10
# step 16 number of successful adv: 6/10
# step 17 number of successful adv: 8/10
# step 18 number of successful adv: 6/10
# step 19 number of successful adv: 8/10
# step 0 number of successful adv: 6/10
# step 1 number of successful adv: 6/10
# step 2 number of successful adv: 6/10
# step 3 number of successful adv: 7/10
# step 4 number of successful adv: 6/10
# step 5 number of successful adv: 5/10
# step 6 number of successful adv: 5/10
# step 7 number of successful adv: 5/10
# step 8 number of successful adv: 5/10
# step 9 number of successful adv: 5/10
# step 10 number of successful adv: 7/10
# step 11 number of successful adv: 6/10
# step 12 number of successful adv: 7/10
# step 13 number of successful adv: 5/10
# step 14 number of successful adv: 7/10
# step 15 number of successful adv: 6/10
# step 16 number of successful adv: 6/10
# step 17 number of successful adv: 7/10
# step 18 number of successful adv: 5/10
# step 19 number of successful adv: 7/10
# step 0 number of successful adv: 8/10
# step 1 number of successful adv: 9/10
# step 2 number of successful adv: 7/10
# step 3 number of successful adv: 9/10
# step 4 number of successful adv: 6/10
# step 5 number of successful adv: 7/10
# step 6 number of successful adv: 8/10
# step 7 number of successful adv: 7/10
# step 8 number of successful adv: 8/10
# step 9 number of successful adv: 8/10
# step 10 number of successful adv: 7/10
# step 11 number of successful adv: 8/10
# step 12 number of successful adv: 7/10
# step 13 number of successful adv: 6/10
# step 14 number of successful adv: 7/10
# step 15 number of successful adv: 7/10
# step 16 number of successful adv: 7/10
# step 17 number of successful adv: 7/10
# step 18 number of successful adv: 6/10
# step 19 number of successful adv: 7/10
# step 0 number of successful adv: 6/10
# step 1 number of successful adv: 7/10
# step 2 number of successful adv: 5/10
# step 3 number of successful adv: 7/10
# step 4 number of successful adv: 7/10
# step 5 number of successful adv: 7/10
# step 6 number of successful adv: 7/10
# step 7 number of successful adv: 8/10
# step 8 number of successful adv: 6/10
# step 9 number of successful adv: 9/10
# step 10 number of successful adv: 7/10
# step 11 number of successful adv: 7/10
# step 12 number of successful adv: 8/10
# step 13 number of successful adv: 9/10
# step 14 number of successful adv: 8/10
# step 15 number of successful adv: 8/10
# step 16 number of successful adv: 10/10
# step 17 number of successful adv: 10/10
# step 18 number of successful adv: 10/10
# step 19 number of successful adv: 8/10
# step 0 number of successful adv: 2/10
# step 1 number of successful adv: 2/10
# step 2 number of successful adv: 3/10
# step 3 number of successful adv: 3/10
# step 4 number of successful adv: 7/10
# step 5 number of successful adv: 3/10
# step 6 number of successful adv: 6/10
# step 7 number of successful adv: 3/10
# step 8 number of successful adv: 6/10
# step 9 number of successful adv: 4/10
# step 10 number of successful adv: 5/10
# step 11 number of successful adv: 6/10
# step 12 number of successful adv: 6/10
# step 13 number of successful adv: 6/10
# step 14 number of successful adv: 7/10
# step 15 number of successful adv: 7/10
# step 16 number of successful adv: 7/10
# step 17 number of successful adv: 7/10
# step 18 number of successful adv: 6/10
# step 19 number of successful adv: 5/10
# step 0 number of successful adv: 6/10
# step 1 number of successful adv: 6/10
# step 2 number of successful adv: 4/10
# step 3 number of successful adv: 6/10
# step 4 number of successful adv: 7/10
# step 5 number of successful adv: 6/10
# step 6 number of successful adv: 8/10
# step 7 number of successful adv: 7/10
# step 8 number of successful adv: 6/10
# step 9 number of successful adv: 9/10
# step 10 number of successful adv: 5/10
# step 11 number of successful adv: 8/10
# step 12 number of successful adv: 8/10
# step 13 number of successful adv: 7/10
# step 14 number of successful adv: 7/10
# step 15 number of successful adv: 7/10
# step 16 number of successful adv: 6/10
# step 17 number of successful adv: 7/10
# step 18 number of successful adv: 8/10
# step 19 number of successful adv: 8/10
# step 0 number of successful adv: 4/10
# step 1 number of successful adv: 4/10
# step 2 number of successful adv: 5/10
# step 3 number of successful adv: 4/10
# step 4 number of successful adv: 5/10
# step 5 number of successful adv: 4/10
# step 6 number of successful adv: 4/10
# step 7 number of successful adv: 5/10
# step 8 number of successful adv: 4/10
# step 9 number of successful adv: 5/10
# step 10 number of successful adv: 5/10
# step 11 number of successful adv: 4/10
# step 12 number of successful adv: 5/10
# step 13 number of successful adv: 4/10
# step 14 number of successful adv: 5/10
# step 15 number of successful adv: 4/10
# step 16 number of successful adv: 5/10
# step 17 number of successful adv: 6/10
# step 18 number of successful adv: 6/10
# step 19 number of successful adv: 5/10
# step 0 number of successful adv: 3/10
# step 1 number of successful adv: 3/10
# step 2 number of successful adv: 3/10
# step 3 number of successful adv: 2/10
# step 4 number of successful adv: 4/10
# step 5 number of successful adv: 4/10
# step 6 number of successful adv: 3/10
# step 7 number of successful adv: 4/10
# step 8 number of successful adv: 4/10
# step 9 number of successful adv: 6/10
# step 10 number of successful adv: 5/10
# step 11 number of successful adv: 3/10
# step 12 number of successful adv: 5/10
# step 13 number of successful adv: 3/10
# step 14 number of successful adv: 6/10
# step 15 number of successful adv: 5/10
# step 16 number of successful adv: 6/10
# step 17 number of successful adv: 5/10
# step 18 number of successful adv: 5/10
# step 19 number of successful adv: 6/10
# 0.42
# 0
# step 0 number of successful adv: 18/100
# step 1 number of successful adv: 26/100
# step 2 number of successful adv: 27/100
# step 3 number of successful adv: 38/100
# step 4 number of successful adv: 32/100
# step 5 number of successful adv: 37/100
# step 6 number of successful adv: 38/100
# step 7 number of successful adv: 37/100
# step 8 number of successful adv: 43/100
# step 9 number of successful adv: 40/100
# loss: 13.098541259765625
# ==> Saving...
# 0.8605
# adversarial example
# 0.1
# 1
# step 0 number of successful adv: 17/100
# step 1 number of successful adv: 22/100
# step 2 number of successful adv: 23/100
# step 3 number of successful adv: 31/100
# step 4 number of successful adv: 35/100
# step 5 number of successful adv: 38/100
# step 6 number of successful adv: 34/100
# step 7 number of successful adv: 39/100
# step 8 number of successful adv: 45/100
# step 9 number of successful adv: 43/100
# loss: 12.48071002960205
# 0.85975
# adversarial example
# 0.10810810810810811
# 2
# step 0 number of successful adv: 12/100
# step 1 number of successful adv: 27/100
# step 2 number of successful adv: 30/100
# step 3 number of successful adv: 29/100
# step 4 number of successful adv: 31/100
# step 5 number of successful adv: 37/100
# step 6 number of successful adv: 34/100
# step 7 number of successful adv: 44/100
# step 8 number of successful adv: 42/100
# step 9 number of successful adv: 43/100
# loss: 14.001851081848145
# 0.85975
# adversarial example
# 0.075
# 3
# step 0 number of successful adv: 11/100
# step 1 number of successful adv: 15/100
# step 2 number of successful adv: 22/100
# step 3 number of successful adv: 30/100
# step 4 number of successful adv: 33/100
# step 5 number of successful adv: 32/100
# step 6 number of successful adv: 35/100
# step 7 number of successful adv: 37/100
# step 8 number of successful adv: 35/100
# step 9 number of successful adv: 38/100
# loss: 10.456941604614258
# 0.858875
# adversarial example
# 0.1
# 4
# step 0 number of successful adv: 9/100
# step 1 number of successful adv: 13/100
# step 2 number of successful adv: 25/100
# step 3 number of successful adv: 20/100
# step 4 number of successful adv: 36/100
# step 5 number of successful adv: 24/100
# step 6 number of successful adv: 41/100
# step 7 number of successful adv: 28/100
# step 8 number of successful adv: 43/100
# step 9 number of successful adv: 27/100
# loss: 12.452561378479004
# 0.857875
# adversarial example
# 0.08
# 5
# step 0 number of successful adv: 12/100
# step 1 number of successful adv: 19/100
# step 2 number of successful adv: 24/100
# step 3 number of successful adv: 34/100
# step 4 number of successful adv: 29/100
# step 5 number of successful adv: 40/100
# step 6 number of successful adv: 33/100
# step 7 number of successful adv: 41/100
# step 8 number of successful adv: 32/100
# step 9 number of successful adv: 43/100
# loss: 13.460226058959961
# ==> Saving...
# 0.857125
# adversarial example
# 0.10810810810810811
# 6
# step 0 number of successful adv: 14/100
# step 1 number of successful adv: 23/100
# step 2 number of successful adv: 26/100
# step 3 number of successful adv: 25/100
# step 4 number of successful adv: 26/100
# step 5 number of successful adv: 32/100
# step 6 number of successful adv: 26/100
# step 7 number of successful adv: 32/100
# step 8 number of successful adv: 36/100
# step 9 number of successful adv: 33/100
# loss: 11.008278846740723
# 0.856125
# adversarial example
# 0.16666666666666666
# 7
# step 0 number of successful adv: 13/100
# step 1 number of successful adv: 21/100
# step 2 number of successful adv: 15/100
# step 3 number of successful adv: 24/100
# step 4 number of successful adv: 29/100
# step 5 number of successful adv: 35/100
# step 6 number of successful adv: 26/100
# step 7 number of successful adv: 36/100
# step 8 number of successful adv: 33/100
# step 9 number of successful adv: 35/100
# loss: 12.913995742797852
# 0.855
# adversarial example
# 0.06451612903225806
# 8
# step 0 number of successful adv: 11/100
# step 1 number of successful adv: 19/100
# step 2 number of successful adv: 30/100
# step 3 number of successful adv: 25/100
# step 4 number of successful adv: 36/100
# step 5 number of successful adv: 33/100
# step 6 number of successful adv: 36/100
# step 7 number of successful adv: 38/100
# step 8 number of successful adv: 35/100
# step 9 number of successful adv: 35/100
# loss: 10.335830688476562
# 0.85325
# adversarial example
# 0.21621621621621623
# 9
# step 0 number of successful adv: 20/100
# step 1 number of successful adv: 20/100
# step 2 number of successful adv: 31/100
# step 3 number of successful adv: 24/100
# step 4 number of successful adv: 31/100
# step 5 number of successful adv: 31/100
# step 6 number of successful adv: 38/100
# step 7 number of successful adv: 32/100
# step 8 number of successful adv: 36/100
# step 9 number of successful adv: 37/100
# loss: 11.136934280395508
# 0.852
# adversarial example
# 0.15151515151515152
# 10
# step 0 number of successful adv: 8/100
# step 1 number of successful adv: 14/100
# step 2 number of successful adv: 24/100
# step 3 number of successful adv: 29/100
# step 4 number of successful adv: 31/100
# step 5 number of successful adv: 32/100
# step 6 number of successful adv: 33/100
# step 7 number of successful adv: 33/100
# step 8 number of successful adv: 35/100
# step 9 number of successful adv: 34/100
# loss: 10.008357048034668
# ==> Saving...
# 0.84975
# adversarial example
# 0.03333333333333333
# 11
# step 0 number of successful adv: 10/100
# step 1 number of successful adv: 16/100
# step 2 number of successful adv: 23/100
# step 3 number of successful adv: 20/100
# step 4 number of successful adv: 26/100
# step 5 number of successful adv: 19/100
# step 6 number of successful adv: 34/100
# step 7 number of successful adv: 19/100
# step 8 number of successful adv: 32/100
# step 9 number of successful adv: 23/100
# loss: 8.32003402709961
# 0.849
# adversarial example
# 0.23809523809523808
# 12
# step 0 number of successful adv: 16/100
# step 1 number of successful adv: 19/100
# step 2 number of successful adv: 24/100
# step 3 number of successful adv: 27/100
# step 4 number of successful adv: 33/100
# step 5 number of successful adv: 28/100
# step 6 number of successful adv: 30/100
# step 7 number of successful adv: 30/100
# step 8 number of successful adv: 31/100
# step 9 number of successful adv: 34/100
# loss: 9.068389892578125
# 0.84825
# adversarial example
# 0.1
# 13
# step 0 number of successful adv: 9/100
# step 1 number of successful adv: 15/100
# step 2 number of successful adv: 21/100
# step 3 number of successful adv: 18/100
# step 4 number of successful adv: 31/100
# step 5 number of successful adv: 24/100
# step 6 number of successful adv: 32/100
# step 7 number of successful adv: 26/100
# step 8 number of successful adv: 36/100
# step 9 number of successful adv: 26/100
# loss: 11.206385612487793
# 0.846875
# adversarial example
# 0.20833333333333334
# 14
# step 0 number of successful adv: 9/100
# step 1 number of successful adv: 16/100
# step 2 number of successful adv: 24/100
# step 3 number of successful adv: 22/100
# step 4 number of successful adv: 33/100
# step 5 number of successful adv: 27/100
# step 6 number of successful adv: 34/100
# step 7 number of successful adv: 30/100
# step 8 number of successful adv: 35/100
# step 9 number of successful adv: 34/100
# loss: 10.816022872924805
# 0.845625
# adversarial example
# 0.15151515151515152
# 15
# step 0 number of successful adv: 7/100
# step 1 number of successful adv: 14/100
# step 2 number of successful adv: 21/100
# step 3 number of successful adv: 29/100
# step 4 number of successful adv: 24/100
# step 5 number of successful adv: 32/100
# step 6 number of successful adv: 27/100
# step 7 number of successful adv: 36/100
# step 8 number of successful adv: 31/100
# step 9 number of successful adv: 35/100
# loss: 11.045879364013672
# ==> Saving...
# 0.8455
# adversarial example
# 0.14705882352941177
# 16
# step 0 number of successful adv: 8/100
# step 1 number of successful adv: 22/100
# step 2 number of successful adv: 20/100
# step 3 number of successful adv: 32/100
# step 4 number of successful adv: 30/100
# step 5 number of successful adv: 32/100
# step 6 number of successful adv: 36/100
# step 7 number of successful adv: 38/100
# step 8 number of successful adv: 36/100
# step 9 number of successful adv: 38/100
# loss: 11.621827125549316
# 0.844
# adversarial example
# 0.11764705882352941
# 17
# step 0 number of successful adv: 12/100
# step 1 number of successful adv: 16/100
# step 2 number of successful adv: 20/100
# step 3 number of successful adv: 29/100
# step 4 number of successful adv: 27/100
# step 5 number of successful adv: 32/100
# step 6 number of successful adv: 28/100
# step 7 number of successful adv: 33/100
# step 8 number of successful adv: 31/100
# step 9 number of successful adv: 35/100
# loss: 10.882189750671387
# 0.84275
# adversarial example
# 0.15151515151515152
# 18
# step 0 number of successful adv: 5/100
# step 1 number of successful adv: 14/100
# step 2 number of successful adv: 18/100
# step 3 number of successful adv: 28/100
# step 4 number of successful adv: 27/100
# step 5 number of successful adv: 34/100
# step 6 number of successful adv: 24/100
# step 7 number of successful adv: 36/100
# step 8 number of successful adv: 27/100
# step 9 number of successful adv: 35/100
# loss: 11.160566329956055
# 0.8425
# adversarial example
# 0.11428571428571428
# 19
# step 0 number of successful adv: 12/100
# step 1 number of successful adv: 18/100
# step 2 number of successful adv: 27/100
# step 3 number of successful adv: 31/100
# step 4 number of successful adv: 32/100
# step 5 number of successful adv: 36/100
# step 6 number of successful adv: 33/100
# step 7 number of successful adv: 38/100
# step 8 number of successful adv: 36/100
# step 9 number of successful adv: 38/100
# loss: 9.423002243041992
# 0.841375
# adversarial example
# 0.15384615384615385
# 20
# step 0 number of successful adv: 11/100
# step 1 number of successful adv: 11/100
# step 2 number of successful adv: 20/100
# step 3 number of successful adv: 28/100
# step 4 number of successful adv: 29/100
# step 5 number of successful adv: 27/100
# step 6 number of successful adv: 31/100
# step 7 number of successful adv: 36/100
# step 8 number of successful adv: 31/100
# step 9 number of successful adv: 37/100
# loss: 10.276915550231934
# ==> Saving...
# 0.842
# adversarial example
# 0.0967741935483871
# 21
# step 0 number of successful adv: 6/100
# step 1 number of successful adv: 13/100
# step 2 number of successful adv: 21/100
# step 3 number of successful adv: 25/100
# step 4 number of successful adv: 26/100
# step 5 number of successful adv: 33/100
# step 6 number of successful adv: 26/100
# step 7 number of successful adv: 32/100
# step 8 number of successful adv: 27/100
# step 9 number of successful adv: 34/100
# loss: 11.875595092773438
# 0.84075
# adversarial example
# 0.0625
# 22
# step 0 number of successful adv: 7/100
# step 1 number of successful adv: 9/100
# step 2 number of successful adv: 24/100
# step 3 number of successful adv: 17/100
# step 4 number of successful adv: 30/100
# step 5 number of successful adv: 24/100
# step 6 number of successful adv: 38/100
# step 7 number of successful adv: 28/100
# step 8 number of successful adv: 39/100
# step 9 number of successful adv: 28/100
# loss: 9.844945907592773
# 0.840375
# adversarial example
# 0.041666666666666664
# 23
# step 0 number of successful adv: 7/100
# step 1 number of successful adv: 17/100
# step 2 number of successful adv: 17/100
# step 3 number of successful adv: 24/100
# step 4 number of successful adv: 28/100
# step 5 number of successful adv: 27/100
# step 6 number of successful adv: 32/100
# step 7 number of successful adv: 27/100
# step 8 number of successful adv: 32/100
# step 9 number of successful adv: 31/100
# loss: 10.014907836914062
# 0.840375
# adversarial example
# 0.14814814814814814
# 24
# step 0 number of successful adv: 9/100
# step 1 number of successful adv: 14/100
# step 2 number of successful adv: 23/100
# step 3 number of successful adv: 19/100
# step 4 number of successful adv: 30/100
# step 5 number of successful adv: 23/100
# step 6 number of successful adv: 27/100
# step 7 number of successful adv: 30/100
# step 8 number of successful adv: 29/100
# step 9 number of successful adv: 31/100
# loss: 10.167003631591797
# 0.839125
# adversarial example
# 0.2
# 25
# step 0 number of successful adv: 10/100
# step 1 number of successful adv: 19/100
# step 2 number of successful adv: 22/100
# step 3 number of successful adv: 34/100
# step 4 number of successful adv: 28/100
# step 5 number of successful adv: 36/100
# step 6 number of successful adv: 28/100
# step 7 number of successful adv: 37/100
# step 8 number of successful adv: 27/100
# step 9 number of successful adv: 39/100
# loss: 9.201263427734375
# ==> Saving...
# 0.838375
# adversarial example
# 0.1388888888888889
# 26
# step 0 number of successful adv: 6/100
# step 1 number of successful adv: 15/100
# step 2 number of successful adv: 22/100
# step 3 number of successful adv: 26/100
# step 4 number of successful adv: 33/100
# step 5 number of successful adv: 33/100
# step 6 number of successful adv: 33/100
# step 7 number of successful adv: 37/100
# step 8 number of successful adv: 32/100
# step 9 number of successful adv: 34/100
# loss: 11.147686004638672
# 0.83725
# adversarial example
# 0.09090909090909091
# 27
# step 0 number of successful adv: 13/100
# step 1 number of successful adv: 13/100
# step 2 number of successful adv: 22/100
# step 3 number of successful adv: 28/100
# step 4 number of successful adv: 27/100
# step 5 number of successful adv: 29/100
# step 6 number of successful adv: 28/100
# step 7 number of successful adv: 26/100
# step 8 number of successful adv: 31/100
# step 9 number of successful adv: 25/100
# loss: 8.774595260620117
# 0.83575
# adversarial example
# 0.21739130434782608
# 28
# step 0 number of successful adv: 6/100
# step 1 number of successful adv: 16/100
# step 2 number of successful adv: 19/100
# step 3 number of successful adv: 31/100
# step 4 number of successful adv: 25/100
# step 5 number of successful adv: 35/100
# step 6 number of successful adv: 27/100
# step 7 number of successful adv: 33/100
# step 8 number of successful adv: 28/100
# step 9 number of successful adv: 36/100
# loss: 10.603124618530273
# 0.833875
# adversarial example
# 0.12121212121212122
# 29
# step 0 number of successful adv: 11/100
# step 1 number of successful adv: 21/100
# step 2 number of successful adv: 26/100
# step 3 number of successful adv: 26/100
# step 4 number of successful adv: 34/100
# step 5 number of successful adv: 33/100
# step 6 number of successful adv: 37/100
# step 7 number of successful adv: 31/100
# step 8 number of successful adv: 35/100
# step 9 number of successful adv: 34/100
# loss: 9.25042724609375
# 0.83325
# adversarial example
# 0.06451612903225806
# 30
# step 0 number of successful adv: 8/100
# step 1 number of successful adv: 5/100
# step 2 number of successful adv: 18/100
# step 3 number of successful adv: 24/100
# step 4 number of successful adv: 23/100
# step 5 number of successful adv: 31/100
# step 6 number of successful adv: 19/100
# step 7 number of successful adv: 31/100
# step 8 number of successful adv: 23/100
# step 9 number of successful adv: 33/100
# loss: 9.487709045410156
# ==> Saving...
# 0.83325
# adversarial example
# 0.125
# 31
# step 0 number of successful adv: 11/100
# step 1 number of successful adv: 12/100
# step 2 number of successful adv: 18/100
# step 3 number of successful adv: 19/100
# step 4 number of successful adv: 25/100
# step 5 number of successful adv: 28/100
# step 6 number of successful adv: 26/100
# step 7 number of successful adv: 28/100
# step 8 number of successful adv: 27/100
# step 9 number of successful adv: 29/100
# loss: 8.073905944824219
# 0.8315
# adversarial example
# 0.15384615384615385
# 32
# step 0 number of successful adv: 12/100
# step 1 number of successful adv: 13/100
# step 2 number of successful adv: 21/100
# step 3 number of successful adv: 26/100
# step 4 number of successful adv: 28/100
# step 5 number of successful adv: 28/100
# step 6 number of successful adv: 31/100
# step 7 number of successful adv: 27/100
# step 8 number of successful adv: 30/100
# step 9 number of successful adv: 27/100
# loss: 9.431782722473145
# 0.8305
# adversarial example
# 0.07142857142857142
# 33
# step 0 number of successful adv: 12/100
# step 1 number of successful adv: 15/100
# step 2 number of successful adv: 19/100
# step 3 number of successful adv: 22/100
# step 4 number of successful adv: 30/100
# step 5 number of successful adv: 27/100
# step 6 number of successful adv: 33/100
# step 7 number of successful adv: 28/100
# step 8 number of successful adv: 38/100
# step 9 number of successful adv: 28/100
# loss: 7.777808666229248
# 0.8295
# adversarial example
# 0.16
# 34
# step 0 number of successful adv: 7/100
# step 1 number of successful adv: 13/100
# step 2 number of successful adv: 18/100
# step 3 number of successful adv: 23/100
# step 4 number of successful adv: 23/100
# step 5 number of successful adv: 30/100
# step 6 number of successful adv: 30/100
# step 7 number of successful adv: 30/100
# step 8 number of successful adv: 27/100
# step 9 number of successful adv: 32/100
# loss: 10.06399154663086
# 0.8285
# adversarial example
# 0.10714285714285714
# 35
# step 0 number of successful adv: 14/100
# step 1 number of successful adv: 15/100
# step 2 number of successful adv: 19/100
# step 3 number of successful adv: 23/100
# step 4 number of successful adv: 28/100
# step 5 number of successful adv: 26/100
# step 6 number of successful adv: 28/100
# step 7 number of successful adv: 27/100
# step 8 number of successful adv: 30/100
# step 9 number of successful adv: 28/100
# loss: 8.883931159973145
# ==> Saving...
# 0.828125
# adversarial example
# 0.20689655172413793
# 36
# step 0 number of successful adv: 12/100
# step 1 number of successful adv: 15/100
# step 2 number of successful adv: 23/100
# step 3 number of successful adv: 21/100
# step 4 number of successful adv: 27/100
# step 5 number of successful adv: 26/100
# step 6 number of successful adv: 26/100
# step 7 number of successful adv: 28/100
# step 8 number of successful adv: 27/100
# step 9 number of successful adv: 30/100
# loss: 8.225890159606934
# 0.827125
# adversarial example
# 0.27586206896551724
# 37
# step 0 number of successful adv: 7/100
# step 1 number of successful adv: 9/100
# step 2 number of successful adv: 14/100
# step 3 number of successful adv: 23/100
# step 4 number of successful adv: 24/100
# step 5 number of successful adv: 31/100
# step 6 number of successful adv: 26/100
# step 7 number of successful adv: 35/100
# step 8 number of successful adv: 29/100
# step 9 number of successful adv: 34/100
# loss: 8.117659568786621
# 0.82725
# adversarial example
# 0.037037037037037035
# 38
# step 0 number of successful adv: 5/100
# step 1 number of successful adv: 16/100
# step 2 number of successful adv: 17/100
# step 3 number of successful adv: 25/100
# step 4 number of successful adv: 22/100
# step 5 number of successful adv: 30/100
# step 6 number of successful adv: 28/100
# step 7 number of successful adv: 30/100
# step 8 number of successful adv: 28/100
# step 9 number of successful adv: 29/100
# loss: 8.750228881835938
# 0.827625
# adversarial example
# 0.10344827586206896
# 39
# step 0 number of successful adv: 12/100
# step 1 number of successful adv: 12/100
# step 2 number of successful adv: 22/100
# step 3 number of successful adv: 25/100
# step 4 number of successful adv: 28/100
# step 5 number of successful adv: 28/100
# step 6 number of successful adv: 31/100
# step 7 number of successful adv: 27/100
# step 8 number of successful adv: 31/100
# step 9 number of successful adv: 26/100
# loss: 7.9294538497924805
# 0.827125
# adversarial example
# 0.04
# 40
# step 0 number of successful adv: 8/100
# step 1 number of successful adv: 18/100
# step 2 number of successful adv: 21/100
# step 3 number of successful adv: 28/100
# step 4 number of successful adv: 28/100
# step 5 number of successful adv: 31/100
# step 6 number of successful adv: 28/100
# step 7 number of successful adv: 31/100
# step 8 number of successful adv: 31/100
# step 9 number of successful adv: 34/100
# loss: 7.797686576843262
# ==> Saving...
# 0.827125
# adversarial example
# 0.1875
# 41
# step 0 number of successful adv: 9/100
# step 1 number of successful adv: 13/100
# step 2 number of successful adv: 19/100
# step 3 number of successful adv: 27/100
# step 4 number of successful adv: 21/100
# step 5 number of successful adv: 31/100
# step 6 number of successful adv: 20/100
# step 7 number of successful adv: 34/100
# step 8 number of successful adv: 18/100
# step 9 number of successful adv: 32/100
# loss: 9.75776481628418
# 0.82625
# adversarial example
# 0.0625
# 42
# step 0 number of successful adv: 1/100
# step 1 number of successful adv: 8/100
# step 2 number of successful adv: 17/100
# step 3 number of successful adv: 19/100
# step 4 number of successful adv: 23/100
# step 5 number of successful adv: 23/100
# step 6 number of successful adv: 29/100
# step 7 number of successful adv: 26/100
# step 8 number of successful adv: 28/100
# step 9 number of successful adv: 24/100
# loss: 7.943332672119141
# 0.824625
# adversarial example
# 0.13636363636363635
# 43
# step 0 number of successful adv: 9/100
# step 1 number of successful adv: 15/100
# step 2 number of successful adv: 16/100
# step 3 number of successful adv: 27/100
# step 4 number of successful adv: 25/100
# step 5 number of successful adv: 30/100
# step 6 number of successful adv: 25/100
# step 7 number of successful adv: 35/100
# step 8 number of successful adv: 29/100
# step 9 number of successful adv: 33/100
# loss: 7.99602746963501
# 0.824875
# adversarial example
# 0.25
# 44
# step 0 number of successful adv: 8/100
# step 1 number of successful adv: 16/100
# step 2 number of successful adv: 22/100
# step 3 number of successful adv: 25/100
# step 4 number of successful adv: 25/100
# step 5 number of successful adv: 30/100
# step 6 number of successful adv: 24/100
# step 7 number of successful adv: 33/100
# step 8 number of successful adv: 28/100
# step 9 number of successful adv: 34/100
# loss: 8.212300300598145
# 0.82475
# adversarial example
# 0.12121212121212122
# 45
# step 0 number of successful adv: 13/100
# step 1 number of successful adv: 15/100
# step 2 number of successful adv: 19/100
# step 3 number of successful adv: 25/100
# step 4 number of successful adv: 27/100
# step 5 number of successful adv: 29/100
# step 6 number of successful adv: 24/100
# step 7 number of successful adv: 35/100
# step 8 number of successful adv: 25/100
# step 9 number of successful adv: 36/100
# loss: 7.326961040496826
# ==> Saving...
# 0.82375
# adversarial example
# 0.3
# 46
# step 0 number of successful adv: 4/100
# step 1 number of successful adv: 2/100
# step 2 number of successful adv: 15/100
# step 3 number of successful adv: 18/100
# step 4 number of successful adv: 20/100
# step 5 number of successful adv: 22/100
# step 6 number of successful adv: 19/100
# step 7 number of successful adv: 25/100
# step 8 number of successful adv: 20/100
# step 9 number of successful adv: 27/100
# loss: 7.444981575012207
# 0.823
# adversarial example
# 0.38461538461538464
# 47
# step 0 number of successful adv: 9/100
# step 1 number of successful adv: 14/100
# step 2 number of successful adv: 23/100
# step 3 number of successful adv: 29/100
# step 4 number of successful adv: 27/100
# step 5 number of successful adv: 34/100
# step 6 number of successful adv: 28/100
# step 7 number of successful adv: 32/100
# step 8 number of successful adv: 30/100
# step 9 number of successful adv: 35/100
# loss: 8.536362648010254
# 0.822625
# adversarial example
# 0.27586206896551724
# 48
# step 0 number of successful adv: 7/100
# step 1 number of successful adv: 13/100
# step 2 number of successful adv: 19/100
# step 3 number of successful adv: 22/100
# step 4 number of successful adv: 25/100
# step 5 number of successful adv: 26/100
# step 6 number of successful adv: 28/100
# step 7 number of successful adv: 28/100
# step 8 number of successful adv: 27/100
# step 9 number of successful adv: 28/100
# loss: 7.162268161773682
# 0.8225
# adversarial example
# 0.28
# 49
# step 0 number of successful adv: 13/100
# step 1 number of successful adv: 21/100
# step 2 number of successful adv: 23/100
# step 3 number of successful adv: 27/100
# step 4 number of successful adv: 27/100
# step 5 number of successful adv: 33/100
# step 6 number of successful adv: 25/100
# step 7 number of successful adv: 36/100
# step 8 number of successful adv: 31/100
# step 9 number of successful adv: 37/100
# loss: 8.408456802368164
# 0.821125
# adversarial example
# 0.23529411764705882
# 0
# step 0 number of successful adv: 14/100
# step 1 number of successful adv: 18/100
# step 2 number of successful adv: 28/100
# step 3 number of successful adv: 31/100
# step 4 number of successful adv: 35/100
# step 5 number of successful adv: 34/100
# step 6 number of successful adv: 35/100
# step 7 number of successful adv: 36/100
# step 8 number of successful adv: 38/100
# step 9 number of successful adv: 34/100
# loss: 8.182092666625977
# ==> Saving...
# 0.821375
# adversarial example
# 0.18181818181818182
# 1
# step 0 number of successful adv: 9/100
# step 1 number of successful adv: 8/100
# step 2 number of successful adv: 16/100
# step 3 number of successful adv: 19/100
# step 4 number of successful adv: 26/100
# step 5 number of successful adv: 22/100
# step 6 number of successful adv: 28/100
# step 7 number of successful adv: 23/100
# step 8 number of successful adv: 28/100
# step 9 number of successful adv: 25/100
# loss: 6.938238143920898
# 0.820875
# adversarial example
# 0.3333333333333333
# 2
# step 0 number of successful adv: 12/100
# step 1 number of successful adv: 16/100
# step 2 number of successful adv: 26/100
# step 3 number of successful adv: 28/100
# step 4 number of successful adv: 31/100
# step 5 number of successful adv: 35/100
# step 6 number of successful adv: 31/100
# step 7 number of successful adv: 38/100
# step 8 number of successful adv: 34/100
# step 9 number of successful adv: 36/100
# loss: 9.416987419128418
# 0.819625
# adversarial example
# 0.08571428571428572
# 3
# step 0 number of successful adv: 7/100
# step 1 number of successful adv: 14/100
# step 2 number of successful adv: 10/100
# step 3 number of successful adv: 20/100
# step 4 number of successful adv: 25/100
# step 5 number of successful adv: 28/100
# step 6 number of successful adv: 30/100
# step 7 number of successful adv: 24/100
# step 8 number of successful adv: 34/100
# step 9 number of successful adv: 24/100
# loss: 6.586230278015137
# 0.8195
# adversarial example
# 0.17391304347826086
# 4
# step 0 number of successful adv: 8/100
# step 1 number of successful adv: 7/100
# step 2 number of successful adv: 12/100
# step 3 number of successful adv: 17/100
# step 4 number of successful adv: 21/100
# step 5 number of successful adv: 27/100
# step 6 number of successful adv: 22/100
# step 7 number of successful adv: 30/100
# step 8 number of successful adv: 24/100
# step 9 number of successful adv: 30/100
# loss: 6.903497695922852
# 0.819125
# adversarial example
# 0.14285714285714285
# 5
# step 0 number of successful adv: 12/100
# step 1 number of successful adv: 15/100
# step 2 number of successful adv: 22/100
# step 3 number of successful adv: 20/100
# step 4 number of successful adv: 30/100
# step 5 number of successful adv: 33/100
# step 6 number of successful adv: 27/100
# step 7 number of successful adv: 35/100
# step 8 number of successful adv: 28/100
# step 9 number of successful adv: 36/100
# loss: 8.159557342529297
# ==> Saving...
# 0.81775
# adversarial example
# 0.30303030303030304
# 6
# step 0 number of successful adv: 10/100
# step 1 number of successful adv: 17/100
# step 2 number of successful adv: 16/100
# step 3 number of successful adv: 26/100
# step 4 number of successful adv: 27/100
# step 5 number of successful adv: 30/100
# step 6 number of successful adv: 29/100
# step 7 number of successful adv: 31/100
# step 8 number of successful adv: 29/100
# step 9 number of successful adv: 31/100
# loss: 7.778090953826904
# 0.817
# adversarial example
# 0.2
# 7
# step 0 number of successful adv: 10/100
# step 1 number of successful adv: 13/100
# step 2 number of successful adv: 15/100
# step 3 number of successful adv: 25/100
# step 4 number of successful adv: 26/100
# step 5 number of successful adv: 34/100
# step 6 number of successful adv: 26/100
# step 7 number of successful adv: 37/100
# step 8 number of successful adv: 29/100
# step 9 number of successful adv: 35/100
# loss: 7.3808746337890625
# 0.815875
# adversarial example
# 0.17647058823529413
# 8
# step 0 number of successful adv: 11/100
# step 1 number of successful adv: 18/100
# step 2 number of successful adv: 19/100
# step 3 number of successful adv: 22/100
# step 4 number of successful adv: 26/100
# step 5 number of successful adv: 27/100
# step 6 number of successful adv: 30/100
# step 7 number of successful adv: 28/100
# step 8 number of successful adv: 31/100
# step 9 number of successful adv: 31/100
# loss: 6.787919521331787
# 0.815375
# adversarial example
# 0.25925925925925924
# 9
# step 0 number of successful adv: 15/100
# step 1 number of successful adv: 17/100
# step 2 number of successful adv: 26/100
# step 3 number of successful adv: 31/100
# step 4 number of successful adv: 32/100
# step 5 number of successful adv: 33/100
# step 6 number of successful adv: 35/100
# step 7 number of successful adv: 35/100
# step 8 number of successful adv: 34/100
# step 9 number of successful adv: 38/100
# loss: 7.498167991638184
# 0.814375
# adversarial example
# 0.14285714285714285
# 10
# step 0 number of successful adv: 8/100
# step 1 number of successful adv: 18/100
# step 2 number of successful adv: 24/100
# step 3 number of successful adv: 26/100
# step 4 number of successful adv: 29/100
# step 5 number of successful adv: 35/100
# step 6 number of successful adv: 31/100
# step 7 number of successful adv: 39/100
# step 8 number of successful adv: 32/100
# step 9 number of successful adv: 38/100
# loss: 7.561578750610352
# ==> Saving...
# 0.813625
# adversarial example
# 0.2777777777777778
# 11
# step 0 number of successful adv: 3/100
# step 1 number of successful adv: 10/100
# step 2 number of successful adv: 12/100
# step 3 number of successful adv: 20/100
# step 4 number of successful adv: 23/100
# step 5 number of successful adv: 27/100
# step 6 number of successful adv: 27/100
# step 7 number of successful adv: 28/100
# step 8 number of successful adv: 26/100
# step 9 number of successful adv: 29/100
# loss: 6.436861038208008
# 0.812875
# adversarial example
# 0.2222222222222222
# 12
# step 0 number of successful adv: 13/100
# step 1 number of successful adv: 12/100
# step 2 number of successful adv: 19/100
# step 3 number of successful adv: 18/100
# step 4 number of successful adv: 24/100
# step 5 number of successful adv: 23/100
# step 6 number of successful adv: 28/100
# step 7 number of successful adv: 24/100
# step 8 number of successful adv: 31/100
# step 9 number of successful adv: 23/100
# loss: 7.043506145477295
# 0.812375
# adversarial example
# 0.22727272727272727
# 13
# step 0 number of successful adv: 4/100
# step 1 number of successful adv: 9/100
# step 2 number of successful adv: 10/100
# step 3 number of successful adv: 19/100
# step 4 number of successful adv: 23/100
# step 5 number of successful adv: 21/100
# step 6 number of successful adv: 26/100
# step 7 number of successful adv: 25/100
# step 8 number of successful adv: 29/100
# step 9 number of successful adv: 24/100
# loss: 7.051362991333008
# 0.810875
# adversarial example
# 0.13043478260869565
# 14
# step 0 number of successful adv: 2/100
# step 1 number of successful adv: 13/100
# step 2 number of successful adv: 15/100
# step 3 number of successful adv: 25/100
# step 4 number of successful adv: 26/100
# step 5 number of successful adv: 30/100
# step 6 number of successful adv: 28/100
# step 7 number of successful adv: 34/100
# step 8 number of successful adv: 29/100
# step 9 number of successful adv: 32/100
# loss: 7.542680263519287
# 0.810625
# adversarial example
# 0.25
# 15
# step 0 number of successful adv: 4/100
# step 1 number of successful adv: 7/100
# step 2 number of successful adv: 11/100
# step 3 number of successful adv: 20/100
# step 4 number of successful adv: 22/100
# step 5 number of successful adv: 24/100
# step 6 number of successful adv: 24/100
# step 7 number of successful adv: 25/100
# step 8 number of successful adv: 25/100
# step 9 number of successful adv: 28/100
# loss: 6.647486686706543
# ==> Saving...
# 0.81025
# adversarial example
# 0.11538461538461539
# 16
# step 0 number of successful adv: 8/100
# step 1 number of successful adv: 16/100
# step 2 number of successful adv: 19/100
# step 3 number of successful adv: 24/100
# step 4 number of successful adv: 24/100
# step 5 number of successful adv: 30/100
# step 6 number of successful adv: 25/100
# step 7 number of successful adv: 31/100
# step 8 number of successful adv: 27/100
# step 9 number of successful adv: 29/100
# loss: 7.57232141494751
# 0.81
# adversarial example
# 0.10344827586206896
# 17
# step 0 number of successful adv: 12/100
# step 1 number of successful adv: 16/100
# step 2 number of successful adv: 22/100
# step 3 number of successful adv: 26/100
# step 4 number of successful adv: 32/100
# step 5 number of successful adv: 30/100
# step 6 number of successful adv: 33/100
# step 7 number of successful adv: 32/100
# step 8 number of successful adv: 31/100
# step 9 number of successful adv: 32/100
# loss: 7.159029960632324
# 0.80975
# adversarial example
# 0.06666666666666667
# 18
# step 0 number of successful adv: 7/100
# step 1 number of successful adv: 13/100
# step 2 number of successful adv: 19/100
# step 3 number of successful adv: 20/100
# step 4 number of successful adv: 21/100
# step 5 number of successful adv: 24/100
# step 6 number of successful adv: 24/100
# step 7 number of successful adv: 27/100
# step 8 number of successful adv: 24/100
# step 9 number of successful adv: 27/100
# loss: 8.235166549682617
# 0.810375
# adversarial example
# 0.28
# 19
# step 0 number of successful adv: 14/100
# step 1 number of successful adv: 19/100
# step 2 number of successful adv: 24/100
# step 3 number of successful adv: 31/100
# step 4 number of successful adv: 28/100
# step 5 number of successful adv: 34/100
# step 6 number of successful adv: 28/100
# step 7 number of successful adv: 35/100
# step 8 number of successful adv: 28/100
# step 9 number of successful adv: 37/100
# loss: 6.335712909698486
# 0.810125
# adversarial example
# 0.19444444444444445
# 20
